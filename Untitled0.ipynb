# %% [markdown]
# <a href="https://colab.research.google.com/github/Marksman007577/Autonomous-Drive/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
# building the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1]),
    tf.keras.layers.Dense(1)
])

# compiling the model
model.compile(optimizer='sgd', loss='mean_squared_error')

Xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

# fit model to the feature and label
model.fit(Xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 531ms/step - loss: 17.7646
# Epoch 2/500
# 1/1 [==============================] - 0s 12ms/step - loss: 10.8767
# Epoch 3/500
# 1/1 [==============================] - 0s 14ms/step - loss: 6.6926
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0100
# Epoch 5/500
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3863
# Epoch 6/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4975
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0564
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8494
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7495
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6942
# Epoch 11/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6566
# Epoch 12/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6260
# ...

# %%
# predict on a new dataset
model.predict([10.0,20.0,21.0,25.0,29.0,35.0])
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5b9c67fa30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 129ms/step
# array([[18.999996],
#        [38.99999 ],
#        [40.999985],
#        [48.999985],
#        [56.99998 ],
#        [68.99997 ]], dtype=float32)
